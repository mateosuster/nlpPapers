# %% [markdown]
# <a href="https://colab.research.google.com/github/mateosuster/nlpPapers/blob/main/code/09_Coherence_by_topic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (20, 3)
sns.set_style("whitegrid")

data1 = pd.read_csv('https://raw.githubusercontent.com/mateosuster/nlpPapers/main/code/data/coherence_by_topic.csv')
data.head()
# Out:
#     coh_tot   coh_avg  coh_avg_pond  topics  seed
# 0  0.370265  0.185133           0.5       2   420
# 1  0.370265  0.185133           0.5       2   421
# 2  0.370265  0.185133           0.5       2   422
# 3  0.370265  0.185133           0.5       2   423
# 4  0.370265  0.185133           0.5       2   424

# %%
ax = sns.boxplot(x="topics", y="coh_tot", data=data, color="w") # hue="topics"
plt.legend([],[], frameon=False)
plt.title('Total coherence')
# Out:
# Text(0.5, 1.0, 'Total coherence')

# %%
plt.scatter(data.topics, data.coh_tot )
plt.plot(data.groupby('topics').coh_tot.mean())
plt.xticks(np.arange( 0, 51, 5.0))
plt.title('Total coherence')
# Out:
# Text(0.5, 1.0, 'Total coherence')

# %%
ax = sns.boxplot(x="topics", y="coh_avg", data=data, color="w") # hue="topics"
plt.legend([],[], frameon=False)
plt.title('Average coherence')
# Out:
# Text(0.5, 1.0, 'Average coherence')

# %%
plt.scatter(data.topics, data.coh_avg )
plt.plot(data.groupby('topics').coh_avg.mean())
plt.xticks(np.arange( 0, 51, 5.0))
plt.title('Average coherence')
# Out:
# Text(0.5, 1.0, 'Average coherence')
